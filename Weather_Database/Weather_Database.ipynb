# %%
import random
import numpy as np
import pandas as pd

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\blake\anaconda3\envs\pythondata\lib\site-packages (0.0.5)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: kdtree>=0.12 in c:\users\blake\anaconda3\envs\pythondata\lib\site-packages (from citipy) (0.16)

# %%
from citipy import citipy

# %%
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 726

# %%
import requests
from configy import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i > 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
    # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

# Loop through all the cities in our list.
for i in range(len(cities)):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
# Out:
# Beginning Data Retrieval
# -------------------
# Processing Record 1 of Set 1 | bluff
# Processing Record 2 of Set 1 | bengkulu
# Processing Record 3 of Set 1 | atar
# Processing Record 4 of Set 1 | touros
# Processing Record 5 of Set 1 | paita
# Processing Record 6 of Set 1 | ponta do sol
# Processing Record 7 of Set 1 | znamenskoye
# Processing Record 8 of Set 1 | aklavik
# Processing Record 9 of Set 1 | vila franca do campo
# Processing Record 10 of Set 1 | tura
# Processing Record 11 of Set 1 | namibe
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | manggar
# Processing Record 14 of Set 1 | mahebourg
# Processing Record 15 of Set 1 | ures
# Processing Record 16 of Set 1 | panaba
# Processing Record 17 of Set 1 | saldanha
# Processing Record 18 of Set 1 | east london
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | banyo
# Processing Record 21 of Set 1 | jamestown
# Processing Record 22 of Set 1 | dzhusaly
# City not found. Skipping...
# Processing Record 23 of Set 1 | sibolga
# Processing Record 24 of Set 1 | victoria
# Processing Record 25 of Set 1 | correntina
# Processing Record 26 of Set 1 | cidreira
# Processing Record 27 of Set 1 | barrow
# Processing Record 28 of Set 1 | simao
# Processing Record 29 of Set 1 | sahy
# Processing Record 30 of Set 1 | khatanga
# Processing Record 31 of Set 1 | port alfred
# Processing Record 32 of Set 1 | fortuna
# Processing Record 33 of Set 1 | caravelas
# Processing Record 34 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 1 | santa isabel do rio negro
# Processing Record 37 of Set 1 | adre
# Processing Record 38 of Set 1 | hinckley
# Processing Record 39 of Set 1 | bairiki
# Processing Record 40 of Set 1 | igarka
# Processing Record 41 of Set 1 | mar del plata
# Processing Record 42 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 1 | mecca
# Processing Record 44 of Set 1 | yining
# Processing Record 45 of Set 1 | atuona
# Processing Record 46 of Set 1 | puerto madryn
# Processing Record 47 of Set 1 | saskylakh
# Processing Record 48 of Set 1 | fukue
# Processing Record 49 of Set 1 | port lincoln
# Processing Record 50 of Set 1 | yellowknife
# Processing Record 51 of Set 1 | marsh harbour
# Processing Record 52 of Set 1 | butaritari
# Processing Record 53 of Set 1 | gat
# Processing Record 54 of Set 1 | tasiilaq
# Processing Record 55 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 56 of Set 1 | naze
# Processing Record 57 of Set 1 | pevek
# Processing Record 58 of Set 1 | saint anthony
# Processing Record 59 of Set 1 | talnakh
# Processing Record 60 of Set 1 | necochea
# Processing Record 61 of Set 1 | koppang
# Processing Record 62 of Set 1 | saint-philippe
# Processing Record 63 of Set 1 | bethel
# Processing Record 64 of Set 1 | nipawin
# Processing Record 65 of Set 1 | vaini
# Processing Record 66 of Set 1 | punta arenas
# Processing Record 67 of Set 1 | shelburne
# Processing Record 68 of Set 1 | pontes e lacerda
# Processing Record 69 of Set 1 | bacuit
# City not found. Skipping...
# Processing Record 70 of Set 1 | cape town
# Processing Record 71 of Set 1 | anori
# Processing Record 72 of Set 1 | hermanus
# Processing Record 73 of Set 1 | avarua
# Processing Record 74 of Set 1 | hasaki
# Processing Record 75 of Set 1 | nanortalik
# Processing Record 76 of Set 1 | san andres
# Processing Record 77 of Set 1 | longyearbyen
# Processing Record 78 of Set 1 | tuktoyaktuk
# Processing Record 79 of Set 1 | qaanaaq
# Processing Record 80 of Set 1 | tilichiki
# Processing Record 81 of Set 1 | kaitangata
# Processing Record 82 of Set 1 | haines junction
# Processing Record 83 of Set 1 | kindu
# Processing Record 84 of Set 1 | lagoa
# Processing Record 85 of Set 1 | provideniya
# Processing Record 86 of Set 1 | half moon bay
# Processing Record 87 of Set 1 | marzuq
# Processing Record 88 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 89 of Set 1 | marawi
# Processing Record 90 of Set 1 | brae
# Processing Record 91 of Set 1 | albany
# Processing Record 92 of Set 1 | itoman
# Processing Record 93 of Set 1 | isangel
# Processing Record 94 of Set 1 | ketchikan
# Processing Record 95 of Set 1 | kodiak
# Processing Record 96 of Set 1 | hithadhoo
# Processing Record 97 of Set 1 | tezu
# Processing Record 98 of Set 1 | nikolskoye
# Processing Record 99 of Set 1 | coihaique
# Processing Record 100 of Set 1 | guiyang
# Processing Record 1 of Set 2 | tiksi
# Processing Record 2 of Set 2 | ahipara
# Processing Record 3 of Set 2 | florida
# Processing Record 4 of Set 2 | castro
# Processing Record 5 of Set 2 | mehamn
# Processing Record 6 of Set 2 | tuggurt
# City not found. Skipping...
# Processing Record 7 of Set 2 | srednekolymsk
# Processing Record 8 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 2 | ribeira grande
# Processing Record 10 of Set 2 | paldiski
# Processing Record 11 of Set 2 | teya
# Processing Record 12 of Set 2 | hobart
# Processing Record 13 of Set 2 | clovis
# Processing Record 14 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 2 | nizwa
# Processing Record 16 of Set 2 | mantua
# Processing Record 17 of Set 2 | arlit
# Processing Record 18 of Set 2 | ancud
# Processing Record 19 of Set 2 | busselton
# Processing Record 20 of Set 2 | faanui
# Processing Record 21 of Set 2 | camana
# Processing Record 22 of Set 2 | kapaa
# Processing Record 23 of Set 2 | bredasdorp
# Processing Record 24 of Set 2 | mataura
# Processing Record 25 of Set 2 | broome
# Processing Record 26 of Set 2 | coahuayana
# Processing Record 27 of Set 2 | kholm
# Processing Record 28 of Set 2 | faya
# Processing Record 29 of Set 2 | puerto ayora
# Processing Record 30 of Set 2 | ejura
# Processing Record 31 of Set 2 | chuy
# Processing Record 32 of Set 2 | gulu
# Processing Record 33 of Set 2 | katherine
# Processing Record 34 of Set 2 | oistins
# Processing Record 35 of Set 2 | port elizabeth
# Processing Record 36 of Set 2 | colares
# Processing Record 37 of Set 2 | biak
# Processing Record 38 of Set 2 | bilma
# Processing Record 39 of Set 2 | hofn
# Processing Record 40 of Set 2 | kuandian
# Processing Record 41 of Set 2 | new norfolk
# Processing Record 42 of Set 2 | kruisfontein
# Processing Record 43 of Set 2 | port augusta
# Processing Record 44 of Set 2 | georgetown
# Processing Record 45 of Set 2 | codrington
# Processing Record 46 of Set 2 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 47 of Set 2 | utinga
# Processing Record 48 of Set 2 | port hardy
# Processing Record 49 of Set 2 | severo-kurilsk
# Processing Record 50 of Set 2 | guerrero negro
# Processing Record 1 of Set 3 | kaseda
# Processing Record 2 of Set 3 | gafargaon
# Processing Record 3 of Set 3 | paradwip
# City not found. Skipping...
# Processing Record 4 of Set 3 | cherskiy
# Processing Record 5 of Set 3 | abay
# Processing Record 6 of Set 3 | narsaq
# Processing Record 7 of Set 3 | cochabamba
# Processing Record 8 of Set 3 | nichinan
# Processing Record 9 of Set 3 | guarapari
# Processing Record 10 of Set 3 | santa vitoria
# Processing Record 11 of Set 3 | hilo
# Processing Record 12 of Set 3 | baherden
# Processing Record 13 of Set 3 | dunedin
# Processing Record 14 of Set 3 | alice springs
# Processing Record 15 of Set 3 | leh
# Processing Record 16 of Set 3 | carnarvon
# Processing Record 17 of Set 3 | mopipi
# Processing Record 18 of Set 3 | klaksvik
# Processing Record 19 of Set 3 | ibra
# Processing Record 20 of Set 3 | yumen
# Processing Record 21 of Set 3 | camacha
# Processing Record 22 of Set 3 | lahaina
# Processing Record 23 of Set 3 | banda aceh
# Processing Record 24 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 3 | bonavista
# Processing Record 26 of Set 3 | clyde river
# Processing Record 27 of Set 3 | genhe
# Processing Record 28 of Set 3 | hambantota
# Processing Record 29 of Set 3 | upernavik
# Processing Record 30 of Set 3 | palimbang
# Processing Record 31 of Set 3 | kaduna
# Processing Record 32 of Set 3 | kavaratti
# Processing Record 33 of Set 3 | saint george
# Processing Record 34 of Set 3 | wewak
# Processing Record 35 of Set 3 | concepcion
# Processing Record 36 of Set 3 | beira
# Processing Record 37 of Set 3 | ilam
# Processing Record 38 of Set 3 | miandrivazo
# Processing Record 39 of Set 3 | luanda
# Processing Record 40 of Set 3 | beloha
# Processing Record 41 of Set 3 | osoyoos
# Processing Record 42 of Set 3 | darhan
# Processing Record 43 of Set 3 | airai
# Processing Record 44 of Set 3 | krasnoturansk
# Processing Record 45 of Set 3 | penalva
# Processing Record 46 of Set 3 | aksay
# Processing Record 47 of Set 3 | turbat
# Processing Record 48 of Set 3 | iglino
# Processing Record 49 of Set 3 | kamenka
# Processing Record 50 of Set 3 | ihosy
# Processing Record 1 of Set 4 | jeremie
# Processing Record 2 of Set 4 | torbay
# Processing Record 3 of Set 4 | duzce
# Processing Record 4 of Set 4 | moose factory
# Processing Record 5 of Set 4 | okulovka
# Processing Record 6 of Set 4 | luderitz
# Processing Record 7 of Set 4 | korla
# Processing Record 8 of Set 4 | evensk
# Processing Record 9 of Set 4 | san patricio
# Processing Record 10 of Set 4 | samana
# Processing Record 11 of Set 4 | kipini
# Processing Record 12 of Set 4 | kholtoson
# Processing Record 13 of Set 4 | zhanatas
# City not found. Skipping...
# Processing Record 14 of Set 4 | shenzhen
# Processing Record 15 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 4 | coquimbo
# Processing Record 17 of Set 4 | esperance
# Processing Record 18 of Set 4 | bambanglipuro
# Processing Record 19 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 20 of Set 4 | chokurdakh
# Processing Record 21 of Set 4 | west fargo
# Processing Record 22 of Set 4 | miraflores
# Processing Record 23 of Set 4 | sao jose da coroa grande
# Processing Record 24 of Set 4 | cabo san lucas
# Processing Record 25 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 26 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 4 | sitka
# Processing Record 28 of Set 4 | hassleholm
# Processing Record 29 of Set 4 | arraial do cabo
# Processing Record 30 of Set 4 | san jose
# Processing Record 31 of Set 4 | kurchum
# Processing Record 32 of Set 4 | lock haven
# Processing Record 33 of Set 4 | igrim
# Processing Record 34 of Set 4 | thompson
# Processing Record 35 of Set 4 | alofi
# Processing Record 36 of Set 4 | lavrentiya
# Processing Record 37 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 4 | xining
# Processing Record 39 of Set 4 | acapulco
# Processing Record 40 of Set 4 | orebro
# Processing Record 41 of Set 4 | dali
# Processing Record 42 of Set 4 | puerto baquerizo moreno
# Processing Record 43 of Set 4 | carauari
# Processing Record 44 of Set 4 | winsford
# Processing Record 45 of Set 4 | beihai
# Processing Record 46 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 4 | vardo
# Processing Record 48 of Set 4 | souillac
# Processing Record 49 of Set 4 | dikson
# Processing Record 50 of Set 4 | muswellbrook
# Processing Record 1 of Set 5 | puerto maldonado
# Processing Record 2 of Set 5 | pitimbu
# Processing Record 3 of Set 5 | crieff
# Processing Record 4 of Set 5 | ankara
# Processing Record 5 of Set 5 | akdepe
# Processing Record 6 of Set 5 | axim
# Processing Record 7 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 8 of Set 5 | iqaluit
# Processing Record 9 of Set 5 | bathsheba
# Processing Record 10 of Set 5 | avera
# Processing Record 11 of Set 5 | beringovskiy
# Processing Record 12 of Set 5 | abu samrah
# Processing Record 13 of Set 5 | port blair
# Processing Record 14 of Set 5 | saryozek
# Processing Record 15 of Set 5 | kendari
# Processing Record 16 of Set 5 | karratha
# Processing Record 17 of Set 5 | yerbogachen
# Processing Record 18 of Set 5 | mizpe ramon
# City not found. Skipping...
# Processing Record 19 of Set 5 | general roca
# Processing Record 20 of Set 5 | cordoba
# Processing Record 21 of Set 5 | kirovskiy
# Processing Record 22 of Set 5 | wageningen
# Processing Record 23 of Set 5 | lebu
# Processing Record 24 of Set 5 | borogontsy
# Processing Record 25 of Set 5 | villefontaine
# Processing Record 26 of Set 5 | palmerston
# Processing Record 27 of Set 5 | baruun-urt
# Processing Record 28 of Set 5 | gboko
# Processing Record 29 of Set 5 | kudahuvadhoo
# Processing Record 30 of Set 5 | granville
# Processing Record 31 of Set 5 | yeppoon
# Processing Record 32 of Set 5 | lasa
# Processing Record 33 of Set 5 | pemagatsel
# Processing Record 34 of Set 5 | areni
# Processing Record 35 of Set 5 | sinop
# Processing Record 36 of Set 5 | hamilton
# Processing Record 37 of Set 5 | floirac
# Processing Record 38 of Set 5 | burnie
# Processing Record 39 of Set 5 | kautokeino
# Processing Record 40 of Set 5 | komsomolskiy
# Processing Record 41 of Set 5 | shu
# Processing Record 42 of Set 5 | khasan
# Processing Record 43 of Set 5 | sobolevo
# Processing Record 44 of Set 5 | sunrise manor
# Processing Record 45 of Set 5 | mnogovershinnyy
# Processing Record 46 of Set 5 | awbari
# Processing Record 47 of Set 5 | sorland
# Processing Record 48 of Set 5 | antananarivo
# Processing Record 49 of Set 5 | nome
# Processing Record 50 of Set 5 | norman wells
# Processing Record 1 of Set 6 | zhanaozen
# Processing Record 2 of Set 6 | belyy yar
# Processing Record 3 of Set 6 | batagay-alyta
# Processing Record 4 of Set 6 | kopyevo
# City not found. Skipping...
# Processing Record 5 of Set 6 | kaele
# Processing Record 6 of Set 6 | tuatapere
# Processing Record 7 of Set 6 | serowe
# Processing Record 8 of Set 6 | jalu
# Processing Record 9 of Set 6 | kualakapuas
# Processing Record 10 of Set 6 | urucara
# Processing Record 11 of Set 6 | durban
# Processing Record 12 of Set 6 | antofagasta
# Processing Record 13 of Set 6 | strelka
# Processing Record 14 of Set 6 | zhitikara
# City not found. Skipping...
# Processing Record 15 of Set 6 | pisco
# Processing Record 16 of Set 6 | lutkun
# Processing Record 17 of Set 6 | gombong
# Processing Record 18 of Set 6 | prieska
# Processing Record 19 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 6 | czestochowa
# Processing Record 21 of Set 6 | tessalit
# Processing Record 22 of Set 6 | bambous virieux
# Processing Record 23 of Set 6 | calama
# Processing Record 24 of Set 6 | hailey
# Processing Record 25 of Set 6 | olbia
# Processing Record 26 of Set 6 | zavallya
# Processing Record 27 of Set 6 | lazaro cardenas
# Processing Record 28 of Set 6 | oktyabrskiy
# Processing Record 29 of Set 6 | celestun
# Processing Record 30 of Set 6 | exeter
# Processing Record 31 of Set 6 | rocha
# Processing Record 32 of Set 6 | bosaso
# Processing Record 33 of Set 6 | sharkan
# Processing Record 34 of Set 6 | casian
# Processing Record 35 of Set 6 | smithers
# Processing Record 36 of Set 6 | laguna
# Processing Record 37 of Set 6 | dingle
# Processing Record 38 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 6 | mitsamiouli
# Processing Record 40 of Set 6 | saratovskaya
# Processing Record 41 of Set 6 | leningradskiy
# Processing Record 42 of Set 6 | chesma
# Processing Record 43 of Set 6 | esmeraldas
# Processing Record 44 of Set 6 | pangoa
# Processing Record 45 of Set 6 | san rafael
# Processing Record 46 of Set 6 | ucluelet
# Processing Record 47 of Set 6 | gambiran
# Processing Record 48 of Set 6 | dakar
# Processing Record 49 of Set 6 | la peca
# Processing Record 50 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 7 | ingham
# Processing Record 2 of Set 7 | sakaiminato
# Processing Record 3 of Set 7 | ilulissat
# Processing Record 4 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 7 | saint-francois
# Processing Record 6 of Set 7 | skibbereen
# Processing Record 7 of Set 7 | te anau
# Processing Record 8 of Set 7 | mubende
# Processing Record 9 of Set 7 | aligudarz
# Processing Record 10 of Set 7 | belaya gora
# Processing Record 11 of Set 7 | tarumovka
# Processing Record 12 of Set 7 | belomorsk
# Processing Record 13 of Set 7 | grand gaube
# Processing Record 14 of Set 7 | sao joao da barra
# Processing Record 15 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 16 of Set 7 | katsuura
# Processing Record 17 of Set 7 | lata
# Processing Record 18 of Set 7 | chaman
# Processing Record 19 of Set 7 | bubaque
# Processing Record 20 of Set 7 | harper
# Processing Record 21 of Set 7 | junin
# Processing Record 22 of Set 7 | harnosand
# Processing Record 23 of Set 7 | male
# Processing Record 24 of Set 7 | ponta delgada
# Processing Record 25 of Set 7 | shache
# Processing Record 26 of Set 7 | berekua
# Processing Record 27 of Set 7 | sembakung
# Processing Record 28 of Set 7 | miri
# Processing Record 29 of Set 7 | pacific grove
# Processing Record 30 of Set 7 | rawson
# Processing Record 31 of Set 7 | tolmezzo
# Processing Record 32 of Set 7 | zarzal
# Processing Record 33 of Set 7 | cheyur
# City not found. Skipping...
# Processing Record 34 of Set 7 | meadow lake
# Processing Record 35 of Set 7 | kirsanov
# Processing Record 36 of Set 7 | ballina
# Processing Record 37 of Set 7 | curitibanos
# Processing Record 38 of Set 7 | ciras
# City not found. Skipping...
# Processing Record 39 of Set 7 | lorengau
# Processing Record 40 of Set 7 | namatanai
# Processing Record 41 of Set 7 | tidore
# City not found. Skipping...
# Processing Record 42 of Set 7 | constitucion
# Processing Record 43 of Set 7 | viedma
# Processing Record 44 of Set 7 | balimo
# City not found. Skipping...
# Processing Record 45 of Set 7 | asau
# Processing Record 46 of Set 7 | prince rupert
# Processing Record 47 of Set 7 | creel
# Processing Record 48 of Set 7 | morant bay
# Processing Record 49 of Set 7 | kavieng
# Processing Record 50 of Set 7 | lure
# Processing Record 1 of Set 8 | muros
# Processing Record 2 of Set 8 | hirara
# Processing Record 3 of Set 8 | tahe
# Processing Record 4 of Set 8 | kitui
# Processing Record 5 of Set 8 | ivnya
# Processing Record 6 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 7 of Set 8 | palana
# Processing Record 8 of Set 8 | praia da vitoria
# Processing Record 9 of Set 8 | egvekinot
# Processing Record 10 of Set 8 | konevo
# Processing Record 11 of Set 8 | xai-xai
# Processing Record 12 of Set 8 | pochutla
# Processing Record 13 of Set 8 | yulara
# Processing Record 14 of Set 8 | golden
# Processing Record 15 of Set 8 | halifax
# Processing Record 16 of Set 8 | fort nelson
# Processing Record 17 of Set 8 | taoudenni
# Processing Record 18 of Set 8 | badaojiang
# City not found. Skipping...
# Processing Record 19 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 8 | barcelos
# Processing Record 21 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 22 of Set 8 | chulumani
# Processing Record 23 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 24 of Set 8 | santa cruz
# Processing Record 25 of Set 8 | araguacu
# Processing Record 26 of Set 8 | homer
# Processing Record 27 of Set 8 | tarbagatay
# Processing Record 28 of Set 8 | richards bay
# Processing Record 29 of Set 8 | verkhnyaya toyma
# Processing Record 30 of Set 8 | outlook
# Processing Record 31 of Set 8 | poum
# Processing Record 32 of Set 8 | samarai
# Processing Record 33 of Set 8 | wukari
# Processing Record 34 of Set 8 | oranjemund
# Processing Record 35 of Set 8 | turukhansk
# Processing Record 36 of Set 8 | mahibadhoo
# Processing Record 37 of Set 8 | jiayuguan
# Processing Record 38 of Set 8 | havelock
# Processing Record 39 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 40 of Set 8 | pangody
# Processing Record 41 of Set 8 | atambua
# Processing Record 42 of Set 8 | borovoy
# Processing Record 43 of Set 8 | lompoc
# Processing Record 44 of Set 8 | kroya
# Processing Record 45 of Set 8 | palmer
# Processing Record 46 of Set 8 | ibanda
# Processing Record 47 of Set 8 | meridian
# Processing Record 48 of Set 8 | upata
# Processing Record 49 of Set 8 | tabialan
# City not found. Skipping...
# Processing Record 50 of Set 8 | chapais
# Processing Record 1 of Set 9 | santa fe
# Processing Record 2 of Set 9 | pingliang
# Processing Record 3 of Set 9 | jaora
# Processing Record 4 of Set 9 | droitwich
# Processing Record 5 of Set 9 | darnah
# Processing Record 6 of Set 9 | port hedland
# Processing Record 7 of Set 9 | mollendo
# Processing Record 8 of Set 9 | mujiayingzi
# Processing Record 9 of Set 9 | hualmay
# Processing Record 10 of Set 9 | rongcheng
# Processing Record 11 of Set 9 | texarkana
# Processing Record 12 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 13 of Set 9 | vung tau
# Processing Record 14 of Set 9 | saint joseph
# Processing Record 15 of Set 9 | ostrovnoy
# Processing Record 16 of Set 9 | tarhunah
# City not found. Skipping...
# Processing Record 17 of Set 9 | sao miguel do iguacu
# Processing Record 18 of Set 9 | poquoson
# Processing Record 19 of Set 9 | poya
# Processing Record 20 of Set 9 | kutum
# Processing Record 21 of Set 9 | grave
# Processing Record 22 of Set 9 | thinadhoo
# Processing Record 23 of Set 9 | launceston
# Processing Record 24 of Set 9 | cacapava do sul
# Processing Record 25 of Set 9 | anqing
# Processing Record 26 of Set 9 | kahta
# Processing Record 27 of Set 9 | norsup
# Processing Record 28 of Set 9 | qom
# Processing Record 29 of Set 9 | dawlatabad
# Processing Record 30 of Set 9 | nishihara
# Processing Record 31 of Set 9 | puerto rico
# Processing Record 32 of Set 9 | meulaboh
# Processing Record 33 of Set 9 | singapore
# Processing Record 34 of Set 9 | verkhnetulomskiy
# Processing Record 35 of Set 9 | tabou
# Processing Record 36 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 37 of Set 9 | valparaiso
# Processing Record 38 of Set 9 | olinda
# Processing Record 39 of Set 9 | waingapu
# Processing Record 40 of Set 9 | kontagora
# Processing Record 41 of Set 9 | okhotsk
# Processing Record 42 of Set 9 | deputatskiy
# Processing Record 43 of Set 9 | kabalo
# Processing Record 44 of Set 9 | sakakah
# Processing Record 45 of Set 9 | sur
# Processing Record 46 of Set 9 | basqal
# Processing Record 47 of Set 9 | bandarbeyla
# Processing Record 48 of Set 9 | segezha
# Processing Record 49 of Set 9 | morehead
# Processing Record 50 of Set 9 | nelson bay
# Processing Record 1 of Set 10 | hay river
# Processing Record 2 of Set 10 | kirensk
# Processing Record 3 of Set 10 | nadym
# Processing Record 4 of Set 10 | dunmore town
# Processing Record 5 of Set 10 | torrington
# Processing Record 6 of Set 10 | berdigestyakh
# Processing Record 7 of Set 10 | hastings
# Processing Record 8 of Set 10 | lumeje
# Processing Record 9 of Set 10 | sambava
# Processing Record 10 of Set 10 | vila velha
# Processing Record 11 of Set 10 | guisa
# Processing Record 12 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 13 of Set 10 | naron
# Processing Record 14 of Set 10 | safaqis
# City not found. Skipping...
# Processing Record 15 of Set 10 | victor harbor
# Processing Record 16 of Set 10 | goulburn
# Processing Record 17 of Set 10 | yamada
# Processing Record 18 of Set 10 | taiyuan
# Processing Record 19 of Set 10 | san ramon
# Processing Record 20 of Set 10 | wonthaggi
# Processing Record 21 of Set 10 | kahului
# Processing Record 22 of Set 10 | badarwas
# Processing Record 23 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 24 of Set 10 | kharagauli
# Processing Record 25 of Set 10 | wattegama
# Processing Record 26 of Set 10 | verkh-usugli
# Processing Record 27 of Set 10 | mount isa
# Processing Record 28 of Set 10 | cooma
# Processing Record 29 of Set 10 | banjar
# Processing Record 30 of Set 10 | vitim
# Processing Record 31 of Set 10 | kamsack
# Processing Record 32 of Set 10 | pueblo nuevo
# Processing Record 33 of Set 10 | sao gabriel da cachoeira
# Processing Record 34 of Set 10 | ryotsu
# Processing Record 35 of Set 10 | shubarshi
# Processing Record 36 of Set 10 | bunbury
# Processing Record 37 of Set 10 | alberton
# Processing Record 38 of Set 10 | marystown
# Processing Record 39 of Set 10 | santo antonio do ica
# Processing Record 40 of Set 10 | luz
# Processing Record 41 of Set 10 | muisne
# Processing Record 42 of Set 10 | boa vista
# Processing Record 43 of Set 10 | avallon
# Processing Record 44 of Set 10 | bilibino
# Processing Record 45 of Set 10 | henties bay
# Processing Record 46 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 10 | along
# Processing Record 48 of Set 10 | aksu
# Processing Record 49 of Set 10 | yenagoa
# Processing Record 50 of Set 10 | khirkiya
# Processing Record 1 of Set 11 | rapid valley
# Processing Record 2 of Set 11 | port moresby
# Processing Record 3 of Set 11 | mikhaylovka
# Processing Record 4 of Set 11 | palauig
# Processing Record 5 of Set 11 | hengyang
# Processing Record 6 of Set 11 | hami
# Processing Record 7 of Set 11 | batticaloa
# Processing Record 8 of Set 11 | san quintin
# Processing Record 9 of Set 11 | dumai
# Processing Record 10 of Set 11 | labuhan
# Processing Record 11 of Set 11 | geraldton
# Processing Record 12 of Set 11 | gorele
# Processing Record 13 of Set 11 | vao
# Processing Record 14 of Set 11 | buchanan
# Processing Record 15 of Set 11 | tateyama
# Processing Record 16 of Set 11 | razdolnoye
# Processing Record 17 of Set 11 | campechuela
# Processing Record 18 of Set 11 | tsimlyansk
# Processing Record 19 of Set 11 | kachug
# Processing Record 20 of Set 11 | phuket
# Processing Record 21 of Set 11 | margate
# Processing Record 22 of Set 11 | grindavik
# Processing Record 23 of Set 11 | bari sadri
# Processing Record 24 of Set 11 | kalmunai
# Processing Record 25 of Set 11 | virginia beach
# Processing Record 26 of Set 11 | betong
# Processing Record 27 of Set 11 | muborak
# Processing Record 28 of Set 11 | los llanos de aridane
# Processing Record 29 of Set 11 | haian
# Processing Record 30 of Set 11 | ugoofaaru
# Processing Record 31 of Set 11 | black river
# Processing Record 32 of Set 11 | pinheiro machado
# Processing Record 33 of Set 11 | lipari
# Processing Record 34 of Set 11 | apartado
# Processing Record 35 of Set 11 | mana
# Processing Record 36 of Set 11 | lucapa
# Processing Record 37 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 38 of Set 11 | kostomuksha
# Processing Record 39 of Set 11 | japura
# Processing Record 40 of Set 11 | lugoba
# Processing Record 41 of Set 11 | lubango
# Processing Record 42 of Set 11 | naliya
# Processing Record 43 of Set 11 | duz
# City not found. Skipping...
# Processing Record 44 of Set 11 | charlestown
# Processing Record 45 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 46 of Set 11 | sept-iles
# Processing Record 47 of Set 11 | lobatse
# Processing Record 48 of Set 11 | rio rancho
# Processing Record 49 of Set 11 | le portel
# Processing Record 50 of Set 11 | ixtapa
# Processing Record 1 of Set 12 | mezen
# Processing Record 2 of Set 12 | anadyr
# Processing Record 3 of Set 12 | jardim do serido
# Processing Record 4 of Set 12 | eyl
# Processing Record 5 of Set 12 | gotsu
# Processing Record 6 of Set 12 | tyup
# Processing Record 7 of Set 12 | makakilo city
# Processing Record 8 of Set 12 | elliot
# Processing Record 9 of Set 12 | kerouane
# Processing Record 10 of Set 12 | bay city
# Processing Record 11 of Set 12 | canutama
# Processing Record 12 of Set 12 | madison
# Processing Record 13 of Set 12 | hawkesbury
# Processing Record 14 of Set 12 | la massana
# Processing Record 15 of Set 12 | uong bi
# Processing Record 16 of Set 12 | kyzyl-suu
# Processing Record 17 of Set 12 | kaputa
# Processing Record 18 of Set 12 | crotone
# Processing Record 19 of Set 12 | tzaneen
# Processing Record 20 of Set 12 | hyeres
# Processing Record 21 of Set 12 | qianan
# Processing Record 22 of Set 12 | kamina
# Processing Record 23 of Set 12 | salalah
# Processing Record 24 of Set 12 | dongkan
# Processing Record 25 of Set 12 | maarianhamina
# Processing Record 26 of Set 12 | zheleznodorozhnyy
# Processing Record 27 of Set 12 | komatipoort
# Processing Record 28 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 29 of Set 12 | pokrovsk
# Processing Record 30 of Set 12 | baracoa
# Processing Record 31 of Set 12 | college
# Processing Record 32 of Set 12 | antoing
# Processing Record 33 of Set 12 | shimoda
# Processing Record 34 of Set 12 | kuytun
# Processing Record 35 of Set 12 | zabolottya
# City not found. Skipping...
# Processing Record 36 of Set 12 | ngaoundere
# Processing Record 37 of Set 12 | mlowo
# Processing Record 38 of Set 12 | whitehorse
# Processing Record 39 of Set 12 | huilong
# Processing Record 40 of Set 12 | carlsbad
# Processing Record 41 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 42 of Set 12 | hervey bay
# Processing Record 43 of Set 12 | ruwi
# Processing Record 44 of Set 12 | sioux lookout
# Processing Record 45 of Set 12 | bien hoa
# Processing Record 46 of Set 12 | mount gambier
# Processing Record 47 of Set 12 | gornopravdinsk
# Processing Record 48 of Set 12 | tapiramuta
# Processing Record 49 of Set 12 | vanimo
# Processing Record 50 of Set 12 | shenkursk
# Processing Record 1 of Set 13 | imbituba
# Processing Record 2 of Set 13 | sao domingos
# Processing Record 3 of Set 13 | buraydah
# Processing Record 4 of Set 13 | gouyave
# Processing Record 5 of Set 13 | bentiu
# Processing Record 6 of Set 13 | waipawa
# Processing Record 7 of Set 13 | the valley
# Processing Record 8 of Set 13 | cockburn town
# Processing Record 9 of Set 13 | christchurch
# Processing Record 10 of Set 13 | yidu
# Processing Record 11 of Set 13 | elko
# Processing Record 12 of Set 13 | san juan
# Processing Record 13 of Set 13 | inongo
# Processing Record 14 of Set 13 | goure
# Processing Record 15 of Set 13 | okha
# Processing Record 16 of Set 13 | jasper
# Processing Record 17 of Set 13 | comodoro rivadavia
# Processing Record 18 of Set 13 | maragogi
# Processing Record 19 of Set 13 | kinablangan
# Processing Record 20 of Set 13 | pokhara
# Processing Record 21 of Set 13 | husavik
# Processing Record 22 of Set 13 | langenzersdorf
# Processing Record 23 of Set 13 | ust-maya
# Processing Record 24 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 25 of Set 13 | zholymbet
# Processing Record 26 of Set 13 | sheoganj
# Processing Record 27 of Set 13 | dukat
# Processing Record 28 of Set 13 | formiga
# Processing Record 29 of Set 13 | marquette
# Processing Record 30 of Set 13 | morondava
# Processing Record 31 of Set 13 | udachnyy
# Processing Record 32 of Set 13 | charlottetown
# Processing Record 33 of Set 13 | yako
# Processing Record 34 of Set 13 | gatton
# Processing Record 35 of Set 13 | achutupo
# Processing Record 36 of Set 13 | maltahohe
# Processing Record 37 of Set 13 | san cristobal
# Processing Record 38 of Set 13 | shieli
# Processing Record 39 of Set 13 | angoche
# Processing Record 40 of Set 13 | quechultenango
# Processing Record 41 of Set 13 | zyryanovsk
# Processing Record 42 of Set 13 | manzhouli
# Processing Record 43 of Set 13 | telica
# Processing Record 44 of Set 13 | bolekhiv
# Processing Record 45 of Set 13 | salinas
# Processing Record 46 of Set 13 | falealupo
# City not found. Skipping...
# Processing Record 47 of Set 13 | royan
# Processing Record 48 of Set 13 | saint-quentin
# Processing Record 49 of Set 13 | kaeng khoi
# Processing Record 50 of Set 13 | adrar
# Processing Record 1 of Set 14 | dunayivtsi
# City not found. Skipping...
# Processing Record 2 of Set 14 | sumbe
# Processing Record 3 of Set 14 | okmulgee
# Processing Record 4 of Set 14 | filimonovo
# Processing Record 5 of Set 14 | sogdiondon
# City not found. Skipping...
# Processing Record 6 of Set 14 | inuvik
# Processing Record 7 of Set 14 | sao filipe
# Processing Record 8 of Set 14 | shar
# Processing Record 9 of Set 14 | prescott valley
# Processing Record 10 of Set 14 | cerritos
# Processing Record 11 of Set 14 | galiwinku
# City not found. Skipping...
# Processing Record 12 of Set 14 | boffa
# Processing Record 13 of Set 14 | ulaangom
# Processing Record 14 of Set 14 | bulgan
# Processing Record 15 of Set 14 | honningsvag
# Processing Record 16 of Set 14 | curup
# Processing Record 17 of Set 14 | obihiro
# Processing Record 18 of Set 14 | alta floresta
# Processing Record 19 of Set 14 | claveria
# Processing Record 20 of Set 14 | gidam
# Processing Record 21 of Set 14 | ambunti
# Processing Record 22 of Set 14 | kerema
# Processing Record 23 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 24 of Set 14 | minab
# Processing Record 25 of Set 14 | davila
# Processing Record 26 of Set 14 | sapai
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Bluff -46.6000  168.3333     54.00        67          51        5.01
# 1    Bengkulu  -3.8004  102.2655     82.11        75          55        1.59
# 2        Atar  20.5169  -13.0499     78.87        23          54        6.02
# 3      Touros  -5.1989  -35.4608     73.40        94          20        4.61
# 4       Paita  -5.0892  -81.1144     69.40        77          91       15.61
# ..        ...      ...       ...       ...       ...         ...         ...
# 662     Gidam  18.9833   81.4000     85.12        59          97        5.41
# 663   Ambunti  -4.2365  142.8448     87.04        73          99        3.36
# 664    Kerema  -7.9631  145.7785     83.86        75          95        4.54
# 665     Minab  27.1467   57.0801     78.80        41           0        2.30
# 666    Davila  18.4726  120.5763     89.60        74          20        9.22
#
#     Country      Description
# 0        NZ    broken clouds
# 1        ID    broken clouds
# 2        MR    broken clouds
# 3        BR       few clouds
# 4        PE  overcast clouds
# ..      ...              ...
# 662      IN  overcast clouds
# 663      PG  overcast clouds
# 664      PG    moderate rain
# 665      IR        clear sky
# 666      PH       few clouds
#
# [667 rows x 9 columns]

# %%
columns = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]

# %%
city_data_df = city_data_df[columns]

# %%
city_data_df
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Bluff      NZ -46.6000  168.3333     54.00        67          51
# 1    Bengkulu      ID  -3.8004  102.2655     82.11        75          55
# 2        Atar      MR  20.5169  -13.0499     78.87        23          54
# 3      Touros      BR  -5.1989  -35.4608     73.40        94          20
# 4       Paita      PE  -5.0892  -81.1144     69.40        77          91
# ..        ...     ...      ...       ...       ...       ...         ...
# 662     Gidam      IN  18.9833   81.4000     85.12        59          97
# 663   Ambunti      PG  -4.2365  142.8448     87.04        73          99
# 664    Kerema      PG  -7.9631  145.7785     83.86        75          95
# 665     Minab      IR  27.1467   57.0801     78.80        41           0
# 666    Davila      PH  18.4726  120.5763     89.60        74          20
#
#      Wind Speed      Description
# 0          5.01    broken clouds
# 1          1.59    broken clouds
# 2          6.02    broken clouds
# 3          4.61       few clouds
# 4         15.61  overcast clouds
# ..          ...              ...
# 662        5.41  overcast clouds
# 663        3.36  overcast clouds
# 664        4.54    moderate rain
# 665        2.30        clear sky
# 666        9.22       few clouds
#
# [667 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
